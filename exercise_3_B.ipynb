# %% [markdown]
# # Exercise 3 B
#
# **Instructions:**
#
# Build a Simple Linear Regression model using **Gradient Descent** to study the linear relationship between the years of experience and salary.

# %% [markdown]
# 1. Import the necessary packages

# %%
# put your answer here

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# 2. Load the salary.csv file

# %%
# put your answer here

df = pd.read_csv('salary.csv')

# %% [markdown]
# 3. Print the first 5 rows of the dataset

# %%
# put your answer here
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.2   39344
# 1              1.4   46206
# 2              1.6   37732
# 3              2.1   43526
# 4              2.3   39892

# %% [markdown]
# 4. Display the general information of the dataframe

# %%
# put your answer here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes

# %% [markdown]
# 5. Visualize the data by creating a scatter plot

# %%
# put your answer here

df.plot(x = 'YearsExperience', y = 'Salary', kind="scatter")
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# 7. Build the model using gradient descent

# %%
# put your answer here

X = df['YearsExperience'].values
y = df['Salary'].values

m = 0
b = 0

L = 0.0009
epochs = 8000

n = float(len(X))

for i in range (epochs):
  y_pred = m * X + b

  d_m = (-2/n) * sum(X * (y - y_pred))
  d_b = (-2/n) * sum(y - y_pred)

  m = m - L * d_m
  b = b - L * d_b

# %% [markdown]
# 8. Print the values of the slope and the intercept
#
# - Display the slope
# - Display the intercept

# %%
# put your answer here

print('Slope: ', m)
print('Y-intercept', b)
# Out:
# Slope:  9624.672354066757
# Y-intercept 23657.814386059024

# %% [markdown]
# 9. Draw the Regression Line

# %%
# put your answer here

y_pred = m*X+b

plt.scatter(X,y)
plt.plot([min(X), max(X)], [min(y_pred), max(y_pred)], color='pink')
plt.show()

# %% [markdown]
# 10. Compute the Sum of Square Error (SSE)

# %%
# put your answer here
data = pd.DataFrame({'Actual Salary': y, 'Predicted Salary': y_pred})

data.head(10)
# Out:
#    Actual Salary  Predicted Salary
# 0          39344      35207.421211
# 1          46206      37132.355682
# 2          37732      39057.290153
# 3          43526      43869.626330
# 4          39892      45794.560800
# 5          56643      52531.831448
# 6          60151      53494.298684
# 7          54446      55419.233154
# 8          64446      55419.233154
# 9          57190      60231.569332

# %%
# put your answer here

sose = str(np.sum(np.square(data['Predicted Salary'] - data['Actual Salary'])))

print ('Residual sum of square is: ', sose)
# Out:
# Residual sum of square is:  947052735.315176
